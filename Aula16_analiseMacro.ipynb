# %% [markdown]
# <a href="https://colab.research.google.com/github/ca724/minha_primeira_analise/blob/main/Aula16_analiseMacro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bibliotecas

# %%
import pandas as pd
import plotnine as p9
import statsmodels.formula.api as smf

# %% [markdown]
# #Coletar os dados

# %%
dados_brutos_ipca = pd.read_json("https://apisidra.ibge.gov.br/values/t/1737/n1/all/v/2265/p/all/d/v2265%202?formato=json")
dados_brutos_ipca
# Out:
#                              NC                 NN  \
# 0    Nível Territorial (Código)  Nível Territorial
# 1                             1             Brasil
# 2                             1             Brasil
# 3                             1             Brasil
# 4                             1             Brasil
# ..                          ...                ...
# 537                           1             Brasil
# 538                           1             Brasil
# 539                           1             Brasil
# 540                           1             Brasil
# 541                           1             Brasil
#
#                              MC                 MN      V              D1C  \
# 0    Unidade de Medida (Código)  Unidade de Medida  Valor  Brasil (Código)
# 1                                                     ...                1
# 2                                                     ...                1
# 3                                                     ...                1
# 4                                                     ...                1
# ..                          ...                ...    ...              ...
# 537                           2                  %   4.24                1
# 538                           2                  %   4.42                1
# 539                           2                  %   4.76                1
# 540                           2                  %   4.87                1
# 541                           2                  %   4.83                1
#
#         D1N                D2C                                    D2N  \
# 0    Brasil  Variável (Código)                               Variável
# 1    Brasil               2265  IPCA - Variação acumulada em 12 meses
# 2    Brasil               2265  IPCA - Variação acumulada em 12 meses
# 3    Brasil               2265  IPCA - Variação acumulada em 12 meses
# 4    Brasil               2265  IPCA - Variação acumulada em 12 meses
# ..      ...                ...                                    ...
# 537  Brasil               2265  IPCA - Variação acumulada em 12 meses
# 538  Brasil               2265  IPCA - Variação acumulada em 12 meses
# 539  Brasil               2265  IPCA - Variação acumulada em 12 meses
# 540  Brasil               2265  IPCA - Variação acumulada em 12 meses
# 541  Brasil               2265  IPCA - Variação acumulada em 12 meses
#
#               D3C             D3N
# 0    Mês (Código)             Mês
# 1          197912   dezembro 1979
# 2          198001    janeiro 1980
# 3          198002  fevereiro 1980
# 4          198003      março 1980
# ..            ...             ...
# 537        202408     agosto 2024
# 538        202409   setembro 2024
# 539        202410    outubro 2024
# 540        202411   novembro 2024
# 541        202412   dezembro 2024
#
# [542 rows x 11 columns]

# %%
dados_brutos_desemprego = pd.read_json("https://apisidra.ibge.gov.br/values/t/6381/n1/all/v/4099/p/all/d/v4099%201?formato=json")
dados_brutos_desemprego
# Out:
#                              NC                 NN  \
# 0    Nível Territorial (Código)  Nível Territorial
# 1                             1             Brasil
# 2                             1             Brasil
# 3                             1             Brasil
# 4                             1             Brasil
# ..                          ...                ...
# 150                           1             Brasil
# 151                           1             Brasil
# 152                           1             Brasil
# 153                           1             Brasil
# 154                           1             Brasil
#
#                              MC                 MN      V              D1C  \
# 0    Unidade de Medida (Código)  Unidade de Medida  Valor  Brasil (Código)
# 1                             2                  %    8.0                1
# 2                             2                  %    7.8                1
# 3                             2                  %    7.7                1
# 4                             2                  %    7.6                1
# ..                          ...                ...    ...              ...
# 150                           2                  %    6.6                1
# 151                           2                  %    6.4                1
# 152                           2                  %    6.2                1
# 153                           2                  %    6.1                1
# 154                           2                  %    6.2                1
#
#         D1N                D2C  \
# 0    Brasil  Variável (Código)
# 1    Brasil               4099
# 2    Brasil               4099
# 3    Brasil               4099
# 4    Brasil               4099
# ..      ...                ...
# 150  Brasil               4099
# 151  Brasil               4099
# 152  Brasil               4099
# 153  Brasil               4099
# 154  Brasil               4099
#
#                                                    D2N  \
# 0                                             Variável
# 1    Taxa de desocupação, na semana de referência, ...
# 2    Taxa de desocupação, na semana de referência, ...
# 3    Taxa de desocupação, na semana de referência, ...
# 4    Taxa de desocupação, na semana de referência, ...
# ..                                                 ...
# 150  Taxa de desocupação, na semana de referência, ...
# 151  Taxa de desocupação, na semana de referência, ...
# 152  Taxa de desocupação, na semana de referência, ...
# 153  Taxa de desocupação, na semana de referência, ...
# 154  Taxa de desocupação, na semana de referência, ...
#
#                           D3C               D3N
# 0    Trimestre Móvel (Código)   Trimestre Móvel
# 1                      201203  jan-fev-mar 2012
# 2                      201204  fev-mar-abr 2012
# 3                      201205  mar-abr-mai 2012
# 4                      201206  abr-mai-jun 2012
# ..                        ...               ...
# 150                    202408  jun-jul-ago 2024
# 151                    202409  jul-ago-set 2024
# 152                    202410  ago-set-out 2024
# 153                    202411  set-out-nov 2024
# 154                    202412  out-nov-dez 2024
#
# [155 rows x 11 columns]

# %% [markdown]
# #Tratamento dos dados

# %%
dados_tratados_ipca = (
    dados_brutos_ipca
    .rename(columns = {"V":"ipca", "D3C":"data"})
    .query("ipca not in['Valor','...']")
    .assign(
        data = lambda x: pd.to_datetime(x.data, format="%Y%m"))
    .assign(ipca = lambda x: x.ipca.astype(float))
    .filter(["data", "ipca"])
    .query("data>= @pd.to_datetime('2004-01-01')")
)
dados_tratados_ipca
# Out:
#           data  ipca
# 290 2004-01-01  7.71
# 291 2004-02-01  6.69
# 292 2004-03-01  5.89
# 293 2004-04-01  5.26
# 294 2004-05-01  5.15
# ..         ...   ...
# 537 2024-08-01  4.24
# 538 2024-09-01  4.42
# 539 2024-10-01  4.76
# 540 2024-11-01  4.87
# 541 2024-12-01  4.83
#
# [252 rows x 2 columns]

# %%
dados_tratados_desemprego = (
    dados_brutos_desemprego
    .rename(columns = {"V":"desemprego", "D3C":"data"})
    .query("desemprego not in['Valor','...']")
    .assign(
        data = lambda x: pd.to_datetime(x.data, format="%Y%m"))
    .assign(desemprego = lambda x: x.desemprego.astype(float))
    .filter(["data", "desemprego"])
    .query("data>= @pd.to_datetime('2004-01-01')")
)
dados_tratados_desemprego
# Out:
#           data  desemprego
# 1   2012-03-01         8.0
# 2   2012-04-01         7.8
# 3   2012-05-01         7.7
# 4   2012-06-01         7.6
# 5   2012-07-01         7.5
# ..         ...         ...
# 150 2024-08-01         6.6
# 151 2024-09-01         6.4
# 152 2024-10-01         6.2
# 153 2024-11-01         6.1
# 154 2024-12-01         6.2
#
# [154 rows x 2 columns]

# %%
dados_cruzados = (
    dados_tratados_ipca
    .set_index("data")
    .join(other= dados_tratados_desemprego.set_index("data"), how = "inner")
    .reset_index()
)
dados_cruzados
# Out:
#           data  ipca  desemprego
# 0   2012-03-01  5.24         8.0
# 1   2012-04-01  5.10         7.8
# 2   2012-05-01  4.99         7.7
# 3   2012-06-01  4.92         7.6
# 4   2012-07-01  5.20         7.5
# ..         ...   ...         ...
# 149 2024-08-01  4.24         6.6
# 150 2024-09-01  4.42         6.4
# 151 2024-10-01  4.76         6.2
# 152 2024-11-01  4.87         6.1
# 153 2024-12-01  4.83         6.2
#
# [154 rows x 3 columns]

# %% [markdown]
# #Análise de dados

# %%
# Como a inflação se comportou no Brasil?
(
    p9.ggplot(dados_tratados_ipca)+
    p9.aes(x="data", y="ipca")+
    p9.geom_line()

)

# %%
#Qual o período com menores e maiores taxas de inflação?
print(dados_tratados_ipca.set_index("data").sort_values("ipca").iloc[0])
print(dados_tratados_ipca.query("ipca == ipca.max()"))
# Out:
# ipca    1.88
# Name: 2020-05-01 00:00:00, dtype: float64
#           data   ipca
# 509 2022-04-01  12.13

# %%
#Qual o valor médio da inflação do Brasil e como é a distribuição de seus valores?
dados_tratados_ipca.ipca.describe()
# Out:
# count    252.000000
# mean       5.711786
# std        2.115706
# min        1.880000
# 25%        4.230000
# 50%        5.480000
# 75%        6.602500
# max       12.130000
# Name: ipca, dtype: float64

# %%
(
    p9.ggplot(dados_tratados_ipca)+
    p9.aes(x="ipca")+
    p9.geom_histogram()
)
# Out:
# /usr/local/lib/python3.11/dist-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 14'. Pick better value with 'binwidth'.

# %%
#O que afeta a inflação? Com qual variável ela se relaciona?
(
    p9.ggplot(dados_cruzados)+
    p9.aes(x = "desemprego", y = "ipca")+
    p9.geom_point()
)

# %%
# Regressão

modelo = smf.ols("ipca ~ desemprego", data= dados_cruzados).fit()
modelo

# %%
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   ipca   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     4.341
# Date:                Fri, 07 Feb 2025   Prob (F-statistic):             0.0389
# Time:                        01:20:50   Log-Likelihood:                -356.23
# No. Observations:                 154   AIC:                             716.5
# Df Residuals:                     152   BIC:                             722.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.4372      0.776      9.585      0.000       5.904       8.970
# desemprego    -0.1556      0.075     -2.084      0.039      -0.303      -0.008
# ==============================================================================
# Omnibus:                       16.951   Durbin-Watson:                   0.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.923
# Skew:                           0.865   Prob(JB):                     4.72e-05
# Kurtosis:                       2.665   Cond. No.                         41.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
(
     p9.ggplot(dados_cruzados)+
    p9.aes(x = "desemprego", y = "ipca")+
    p9.geom_point()+
    p9.geom_smooth(method = "lm")
 )
